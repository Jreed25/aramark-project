# %% [markdown]
# # Aramark–Avendra Spend Analysis (EDA)
#
# ## Objective
# This notebook explores the Aramark–Avendra dataset to identify spending patterns across customers, industries, locations, and product categories.
#
# We aim to:
# - Understand spending distribution
# - Identify key drivers of spend
# - Explore geographic and business differences
# - Generate insights for future modeling

# %% [markdown]
# ## Import Libraries

# %%
# !pip install pandas numpy matplotlib seaborn scipy statsmodels scikit-learn pyarrow polars
# Out:
# Requirement already satisfied: pandas in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.0.2)
# Requirement already satisfied: numpy in /usr/local/python/3.12.1/lib/python3.12/site-packages (2.4.4)
# Requirement already satisfied: matplotlib in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.10.8)
# Requirement already satisfied: seaborn in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.13.2)
# Collecting scipy
#   Downloading scipy-1.17.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting statsmodels
#   Downloading statsmodels-0.14.6-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Collecting pyarrow
#   Downloading pyarrow-23.0.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.1 kB)
# Collecting polars
#   Downloading polars-1.39.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting polars-runtime-32==1.39.3 (from polars)
#   Downloading polars_runtime_32-1.39.3-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading scipy-1.17.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 34.6 MB/s  0:00:016m0:00:0100:01
# Downloading statsmodels-0.14.6-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 29.7 MB/s  0:00:006m0:00:01
# Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 35.9 MB/s  0:00:006m0:00:01
# Downloading pyarrow-23.0.1-cp312-cp312-manylinux_2_28_x86_64.whl (47.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 30.1 MB/s  0:00:016m0:00:0100:01
# Downloading polars-1.39.3-py3-none-any.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 824.0/824.0 kB 21.4 MB/s  0:00:00
# Downloading polars_runtime_32-1.39.3-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (46.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 36.9 MB/s  0:00:016m0:00:01
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, pyarrow, polars-runtime-32, patsy, joblib, scikit-learn, polars, statsmodels
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [statsmodels] [statsmodels]]e-32]
# Successfully installed joblib-1.5.3 patsy-1.0.2 polars-1.39.3 polars-runtime-32-1.39.3 pyarrow-23.0.1 scikit-learn-1.8.0 scipy-1.17.1 statsmodels-0.14.6 threadpoolctl-3.6.0
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Data

# %%
DATA_PATH = None  # set this when file is available

if DATA_PATH:
    df = pd.read_csv(DATA_PATH)
    display(df.head())
else:
    print("Dataset not loaded yet. Waiting for file access.")
# Out:
# Dataset not loaded yet. Waiting for file access.

# %% [markdown]
# ## Dataset Overview
# We first inspect the structure of the dataset including shape, data types, and summary statistics.

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.shape
#
# NameError: name 'df' is not defined

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# ## Data Cleaning
# We check for missing values and handle basic cleaning before analysis.

# %%
df.isnull().sum().sort_values(ascending=False)

# %%
# Basic cleaning (adjust if needed)
df = df.dropna(subset=["Spend Random Factor"])

# %% [markdown]
# ## Exploratory Analysis

# %% [markdown]
# ## Spend by Category Level 1
# We analyze which product categories contribute the most to total spend.

# %%
category_spend = df.groupby("Category Level 1")["Spend Random Factor"].sum().sort_values(ascending=False)
category_spend

# %%
category_spend.plot(kind="bar", figsize=(10,5))
plt.title("Total Spend by Category Level 1")
plt.ylabel("Spend")
plt.show()

# %% [markdown]
# ## Spend by State
# We analyze geographic distribution of spend across US states.

# %%
state_spend = df.groupby("State")["Spend Random Factor"].sum().sort_values(ascending=False)
state_spend.head(10)

# %%
state_spend.head(10).plot(kind="bar", figsize=(10,5))
plt.title("Top 10 States by Spend")
plt.show()

# %% [markdown]
# ## Spend by Business Entity Type
# We compare spending behavior across different industries.

# %%
business_spend = df.groupby("Business Entity Type")["Spend Random Factor"].mean().sort_values(ascending=False)
business_spend

# %%
business_spend.plot(kind="bar", figsize=(10,5))
plt.title("Average Spend by Business Type")
plt.show()

# %% [markdown]
# ## Ecommerce vs Non-Ecommerce Spending
# We analyze whether ecommerce adoption impacts spending behavior.

# %%
ecom_spend = df.groupby("Ecommerce Status")["Spend Random Factor"].mean()
ecom_spend

# %%
ecom_spend.plot(kind="bar")
plt.title("Ecommerce vs Non-Ecommerce Spend")
plt.show()

# %% [markdown]
# ## Spend by City
# We examine high-spending cities in the dataset.

# %%
city_spend = df.groupby("City")["Spend Random Factor"].sum().sort_values(ascending=False)
city_spend.head(10)

# %% [markdown]
# ## Key Insights from EDA
#
# - Certain product categories dominate total spend
# - Spending is highly concentrated in specific states
# - Business type strongly influences average spend
# - Ecommerce adoption may impact purchasing behavior
# - Clear opportunity for segmentation and prediction modeling

# %% [markdown]
# Saving Results

# %%
category_spend.to_csv("../results/category_spend.csv")
state_spend.to_csv("../results/state_spend.csv")
city_spend.to_csv("../results/city_spend.csv")

# %%
plt.savefig("../results/state_spend.png")

# %% [markdown]
# ## Next Steps
#
# Based on EDA, the project will proceed in one of the following directions:
#
# 1. Customer segmentation using clustering
# 2. Spend prediction using machine learning
# 3. Association rule mining for category relationships
#
# Final direction will be chosen based on patterns observed in this analysis.
